# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
### df is list but df[0] is a DataFrame

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age' , 'GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6C26-E0CC
#
#  Directory of C:\Users\poswa\Pandass
#
# 08-10-2022  11:38 AM    <DIR>          .
# 08-10-2022  11:38 AM    <DIR>          ..
# 08-10-2022  11:30 AM    <DIR>          .ipynb_checkpoints
# 08-10-2022  11:14 AM            90,261 my1.ipynb
# 08-10-2022  11:38 AM            78,961 NBA.csv
# 08-10-2022  11:38 AM           577,158 pandas day 2.ipynb
# 08-10-2022  11:29 AM           292,824 PandasLec1.ipynb
# 08-10-2022  10:42 AM            37,423 Untitled.ipynb
#                5 File(s)      1,076,627 bytes
#                3 Dir(s)  136,459,624,448 bytes free

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[0].to_csv('cricket.csv' , index = False )

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 2  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...
# 3  India v West Indies at Kolkata, 3rd T20I, Feb ...

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
#in the dict passed as string the list in values of every key must have same 'len' otherwise when converting to DataFram
# there would be error
#if ever work with a dict where the value list have differ len or one of them has 0 len then try to remove them then execute

# %%
#here we use 3 """ bcoz in json below we pass string(pass dict as string but not dict itself) not dictionary 
#, if pass only dict then error occurs

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result  = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
pd.DataFrame(result['tech'])  # result[tech] returns list so we convert it to DataFrame
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
result['tech']
# Out:
# ['ML', 'DL', 'CV']

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1 = d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

#it converting the json data to DATAFRAME 
#the result has data inside data like complete dict in single col
# to avoid this and get raw data we use request
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/49005  1401793191
# 1     https://github.com/pandas-dev/pandas/pull/49004  1401686191
# 2   https://github.com/pandas-dev/pandas/issues/49003  1401674993
# 3     https://github.com/pandas-dev/pandas/pull/49002  1401670247
# 4   https://github.com/pandas-dev/pandas/issues/49001  1401662423
# 5     https://github.com/pandas-dev/pandas/pull/49000  1401537211
# 6     https://github.com/pandas-dev/pandas/pull/48999  1401517256
# 7   https://github.com/pandas-dev/pandas/issues/48998  1401472418
# 8     https://github.com/pandas-dev/pandas/pull/48997  1401467453
# 9     https://github.com/pandas-dev/pandas/pull/48996  1401465363
# 10    https://github.com/pandas-dev/pandas/pull/48995  1401461137
# 11  https://github.com/pandas-dev/pandas/issues/48991  1401226127
# 12    https://github.com/pandas-dev/pandas/pull/48990  1401123136
# 13  https://github.com/pandas-dev/pandas/issues/48988  1401012917
# 14  https://github.com/pandas-dev/pandas/issues/48986  1400944644
# 15    https://github.com/pandas-dev/pandas/pull/48985  1400902684
# 16    https://github.com/pandas-dev/pandas/pull/48984  1400834210
# 17  https://github.com/pandas-dev/pandas/issues/48983  1400819533
# 18    https://github.com/pandas-dev/pandas/pull/48982  1400807015
# 19    https://github.com/pandas-dev/pandas/pull/48981  1400622262
# 20  https://github.com/pandas-dev/pandas/issues/48979  1400364547
# 21  https://github.com/pandas-dev/pandas/issues/48978  1400281534
# 22    https://github.com/pandas-dev/pandas/pull/48977  1400211273
# 23  https://github.com/pandas-dev/pandas/issues/48974  1400053706
# 24    https://github.com/pandas-dev/pandas/pull/48973  1400041573
# 25    https://github.com/pandas-dev/pandas/pull/48972  1399969018
# 26    https://github.com/pandas-dev/pandas/pull/48971  1399659123
# 27  https://github.com/pandas-dev/pandas/issues/48967  1399112465
# 28    https://github.com/pandas-dev/pandas/pull/48966  1398855129
# 29  https://github.com/pandas-dev/pandas/issues/48964  1398413829
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85AbTgP   49005
# 1   PR_kwDOAA0YD85Aa9EU   49004
# 2    I_kwDOAA0YD85Ti9zx   49003
# 3   PR_kwDOAA0YD85Aa5os   49002
# 4    I_kwDOAA0YD85Ti6vX   49001
# 5   PR_kwDOAA0YD85AadOY   49000
# 6   PR_kwDOAA0YD85AaY-G   48999
# 7    I_kwDOAA0YD85TiMWi   48998
# 8   PR_kwDOAA0YD85AaOlS   48997
# 9   PR_kwDOAA0YD85AaOIj   48996
# 10  PR_kwDOAA0YD85AaNPn   48995
# 11   I_kwDOAA0YD85ThQOP   48991
# 12  PR_kwDOAA0YD85AZE4T   48990
# 13   I_kwDOAA0YD85TgcK1   48988
# 14   I_kwDOAA0YD85TgLgE   48986
# 15  PR_kwDOAA0YD85AYVgm   48985
# 16  PR_kwDOAA0YD85AYHEB   48984
# 17   I_kwDOAA0YD85Tfs9N   48983
# 18  PR_kwDOAA0YD85AYBZC   48982
# 19  PR_kwDOAA0YD85AXaPI   48981
# 20   I_kwDOAA0YD85Td94D   48979
# 21   I_kwDOAA0YD85Tdpm-   48978
# 22  PR_kwDOAA0YD85AWCAO   48977
# 23   I_kwDOAA0YD85Tcx_K   48974
# 24  PR_kwDOAA0YD85AVdO7   48973
# 25  PR_kwDOAA0YD85AVNNt   48972
# 26  PR_kwDOAA0YD85AUIhH   48971
# 27   I_kwDOAA0YD85TZMMR   48967
# 28  PR_kwDOAA0YD85ARVAK   48966
# 29   I_kwDOAA0YD85TWhoF   48964
#
#                                                 title  ... closed_at  \
# 0   DOC: Fix typos and standardize spelling of "Gi...  ...       NaT
# 1        CLN/TST: Use fixture instead of setup_method  ...       NaT
# 2                  BUG: .astype(int) in Window vs Mac  ...       NaT
# 3   Backport PR #48412 on branch 1.5.x (BUG: safe_...  ...       NaT
# 4      REF: Define ops on Resampler as normal methods  ...       NaT
# 5   CLN/TST: Remove testing ArrowExtensionArray in...  ...       NaT
# 6                            CLN: test_nanops/take.py  ...       NaT
# 7              Copy-on-Write follow-up overview issue  ...       NaT
# 8   Backport PR #48987 on branch 1.5.x (REG: Fix r...  ...       NaT
# 9   BUG: CoW - correctly track references for chai...  ...       NaT
# 10       REGR: to_parquet raising with bytes filename  ...       NaT
# 11                                  RLS: pandas 1.5.1  ...       NaT
# 12  DOC: replace developer meeting with contributo...  ...       NaT
# 13       CI: pydata sphinx theme 0.11 broke doc build  ...       NaT
# 14  ENH: Allow hierarchical sorting on MultiIndex,...  ...       NaT
# 15            DOC: Improve documented types for merge  ...       NaT
# 16  DOC: Update xdist to provide more speed-up opt...  ...       NaT
# 17  ENH: allow pct change to generate ghost dates ...  ...       NaT
# 18  made changes to resolve unsupported-assignment...  ...       NaT
# 19  BUG: groupby(..., dropna=False) drops null val...  ...       NaT
# 20  API: Series[td64].astype("timedelta64[unsuppor...  ...       NaT
# 21  BUG: Chained urls (allowed by fsspec) not reco...  ...       NaT
# 22            #48832: GL08 - Added missing docstrings  ...       NaT
# 23                         PERF: cast np.str_ to str?  ...       NaT
# 24                CI: Bump timeouts Python dev builds  ...       NaT
# 25  ENH: Add ability to style axis names with `Sty...  ...       NaT
# 26   BUG: 'Series.to_numpy(dtype=, na_value=)' beh...  ...       NaT
# 27             PERF: Slow pandas import on Kubernetes  ...       NaT
# 28  BUG: pd.compare does not recognize differences...  ...       NaT
# 29  PERF: `pd.util.hash_pandas_object` slower on `...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0         CONTRIBUTOR                NaN    0.0
# 1              MEMBER                NaN    0.0
# 2                NONE                NaN    NaN
# 3                NONE                NaN    0.0
# 4              MEMBER                NaN    NaN
# 5              MEMBER                NaN    0.0
# 6              MEMBER                NaN    0.0
# 7              MEMBER                NaN    NaN
# 8                NONE                NaN    0.0
# 9              MEMBER                NaN    0.0
# 10             MEMBER                NaN    0.0
# 11             MEMBER                NaN    NaN
# 12        CONTRIBUTOR                NaN    0.0
# 13             MEMBER                NaN    NaN
# 14               NONE                NaN    NaN
# 15        CONTRIBUTOR                NaN    0.0
# 16        CONTRIBUTOR                NaN    0.0
# 17               NONE                NaN    NaN
# 18               NONE                NaN    0.0
# 19             MEMBER                NaN    1.0
# 20             MEMBER                NaN    NaN
# 21               NONE                NaN    NaN
# 22               NONE                NaN    1.0
# 23             MEMBER                NaN    NaN
# 24             MEMBER                NaN    0.0
# 25        CONTRIBUTOR                NaN    1.0
# 26             MEMBER                NaN    1.0
# 27               NONE                NaN    NaN
# 28               NONE                NaN    0.0
# 29        CONTRIBUTOR                NaN    NaN
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23                                                NaN
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                                  body  \
# 0   ## Proposed changes\r\n\r\n1. Fix some typos. ...
# 1   - [x] [Tests added and passed](https://pandas....
# 2   ### Pandas version checks\r\n\r\n- [X] I have ...
# 3   Backport PR #48412: BUG: safe_sort losing Mult...
# 4   Ref: https://github.com/pandas-dev/pandas/pull...
# 5   closes https://github.com/pandas-dev/pandas/is...
# 6   - [x] [Tests added and passed](https://pandas....
# 7   An initial implementation was merged in https:...
# 8   Backport PR #48987: REG: Fix regression in ass...
# 9   I encountered a bug in the initial implementat...
# 10  - [x] closes #48944 (Replace xxxx with the Git...
# 11  It's been more than two weeks since the the re...
# 12  Updating the developer meeting page to include...
# 13  See https://github.com/pandas-dev/pandas/actio...
# 14  ### Feature Type\n\n- [X] Adding new functiona...
# 15  Correct list of supported types in docs\r\nRem...
# 16  👋 I was working on a more elaborate solution t...
# 17  ### Feature Type\n\n- [ ] Adding new functiona...
# 18  - [x] closes #48855 partially\r\n- [x ] Solves...
# 19  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 20  ```python\r\nser = pd.Series([1e15, 2e15, 3e15...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  ## In progress\r\n\r\n- [X] closes #48832\r\n-...
# 23  xref https://github.com/pandas-dev/pandas/pull...
# 24  e.g. https://github.com/pandas-dev/pandas/acti...
# 25  - [ ] closes #48936\r\n    - [x] apply_index\r...
# 26  - [x] closes #48951 (Replace xxxx with the Git...
# 27  ### Pandas version checks\n\n- [X] I have chec...
# 28  in  `pd.compare` if any comparisons result in ...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49005',
#   'id': 1401793191,
#   'node_id': 'PR_kwDOAA0YD85AbTgP',
#   'number': 49005,
#   'title': 'DOC: Fix typos and standardize spelling of "GitHub"  and "macOS"',
#   'user': {'login': 'gcbeltramini',
#    'id': 9801748,
#    'node_id': 'MDQ6VXNlcjk4MDE3NDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9801748?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gcbeltramini',
#    'html_url': 'https://github.com/gcbeltramini',
#    'followers_url': 'https://api.github.com/users/gcbeltramini/followers',
#    'following_url': 'https://api.github.com/users/gcbeltramini/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gcbeltramini/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gcbeltramini/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gcbeltramini/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gcbeltramini/orgs',
#    'repos_url': 'https://api.github.com/users/gcbeltramini/repos',
#    'events_url': 'https://api.github.com/users/gcbeltramini/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gcbeltramini/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-10-08T02:30:47Z',
#   'updated_at': '2022-10-08T02:31:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49005',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49005',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49005.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49005.patch',
#    'merged_at': None},
#   'body': '## Proposed changes\r\n\r\n1. Fix some typos. They were found with:\r\n\r\n   ```shell\r\n   brew install aspell\r\n   \r\n   find . -type f -exec cat \'{}\' \\; |\r\n     aspell -a |\r\n     grep -v \'*\' |\r\n     sed \'/^$/d\' |\r\n     cut -d \' \' -f 2 |\r\n     sort -u\r\n   ```\r\n\r\n   The output was visually inspected to find the typos.\r\n\r\n3. Standardize spelling of "GitHub". The official spelling of "GitHub" can be seen in the title of page <https://github.com/>.\r\n4. Standardize spelling of "macOS". The Apple operating system was called "Mac OS X" in versions 10.0-10.7, then "OS X" in versions 10.8-10.11, and finally "macOS" since version 10.12, released in 2016 (<https://en.wikipedia.org/wiki/MacOS#Release_history>).\r\n\r\n## Checklist\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49004',
#   'id': 1401686191,
#   'node_id': 'PR_kwDOAA0YD85Aa9EU',
#   'number': 49004,
#   'title': 'CLN/TST: Use fixture instead of setup_method',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-10-07T21:37:19Z',
#   'updated_at': '2022-10-07T22:48:04Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49004',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49004',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49004.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49004.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49003',
#   'id': 1401674993,
#   'node_id': 'I_kwDOAA0YD85Ti9zx',
#   'number': 49003,
#   'title': 'BUG: .astype(int) in Window vs Mac',
#   'user': {'login': 'FeiLi1996',
#    'id': 88912209,
#    'node_id': 'MDQ6VXNlcjg4OTEyMjA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88912209?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FeiLi1996',
#    'html_url': 'https://github.com/FeiLi1996',
#    'followers_url': 'https://api.github.com/users/FeiLi1996/followers',
#    'following_url': 'https://api.github.com/users/FeiLi1996/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/FeiLi1996/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/FeiLi1996/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/FeiLi1996/subscriptions',
#    'organizations_url': 'https://api.github.com/users/FeiLi1996/orgs',
#    'repos_url': 'https://api.github.com/users/FeiLi1996/repos',
#    'events_url': 'https://api.github.com/users/FeiLi1996/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/FeiLi1996/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-10-07T21:19:36Z',
#   'updated_at': '2022-10-07T23:08:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nHypothetical example. I can\'t give an actual example because it is company stuff,\r\n```python\r\nipdb> ids.astype(int) #on Mac\r\nid(before)      id(after) \r\n1818726176      1818726176  \r\n1881879486      1881879486  \r\n2590366906      2590366906 \r\n\r\nipdb> ids.astype(int) #on Window\r\nid(before)      id(after) \r\n1818726176      1818726176\r\n1881879486      1881879486\r\n2590366906     -1704600390\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nI encounter an issue similiar to this one on stackoverflow\r\nhttps://stackoverflow.com/questions/67796096/working-around-the-windows-numpy-astypeint-bug-in-pandas\r\n\r\nThe story is that my coworker was using Mac and I was using Window. We were getting different numbers in our report. Discrepancy of 179  counts vs 1730 counts of something.\r\n\r\nI debugged everyline of code until I got the change at ".astype(int)". For some reason , Mac decided to turn it to int64 and Window turned it into int32. However, some of the ids number are over the cap of int32, so the computer changed the number to something else like you seen the example above 2590366906   >>> -1704600390 . Pandas didn\'t throw an error or give me a warning. So I  did a left join down the line on the id=id and lots of my data were gone.\r\n\r\n\r\n\r\n\r\n### Expected Behavior\r\n\r\nThe expected behavior should be that Pandas throw an error or at least give me a warning that this happened.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.8.3.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19041\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 41.2.0\r\npip              : 19.2.3\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : 1.0.9\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.0\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.1\r\nsnappy           : None\r\nsqlalchemy       : 1.4.41\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49002',
#   'id': 1401670247,
#   'node_id': 'PR_kwDOAA0YD85Aa5os',
#   'number': 49002,
#   'title': 'Backport PR #48412 on branch 1.5.x (BUG: safe_sort losing MultiIndex dtypes)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
#    'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#    'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#    'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#    'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meeseeksmachine/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 93,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-10-07T23:43:34Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-10-07T21:12:40Z',
#   'updated_at': '2022-10-07T21:12:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49002',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49002',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49002.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49002.patch',
#    'merged_at': None},
#   'body': 'Backport PR #48412: BUG: safe_sort losing MultiIndex dtypes',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49001',
#   'id': 1401662423,
#   'node_id': 'I_kwDOAA0YD85Ti6vX',
#   'number': 49001,
#   'title': 'REF: Define ops on Resampler as normal methods',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 74975453,
#     'node_id': 'MDU6TGFiZWw3NDk3NTQ1Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Resample',
#     'name': 'Resample',
#     'color': '207de5',
#     'default': False,
#     'description': 'resample method'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'erikcek',
#    'id': 32076170,
#    'node_id': 'MDQ6VXNlcjMyMDc2MTcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32076170?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/erikcek',
#    'html_url': 'https://github.com/erikcek',
#    'followers_url': 'https://api.github.com/users/erikcek/followers',
#    'following_url': 'https://api.github.com/users/erikcek/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/erikcek/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/erikcek/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/erikcek/subscriptions',
#    'organizations_url': 'https://api.github.com/users/erikcek/orgs',
#    'repos_url': 'https://api.github.com/users/erikcek/repos',
#    'events_url': 'https://api.github.com/users/erikcek/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/erikcek/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'erikcek',
#     'id': 32076170,
#     'node_id': 'MDQ6VXNlcjMyMDc2MTcw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/32076170?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/erikcek',
#     'html_url': 'https://github.com/erikcek',
#     'followers_url': 'https://api.github.com/users/erikcek/followers',
#     'following_url': 'https://api.github.com/users/erikcek/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/erikcek/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/erikcek/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/erikcek/subscriptions',
#     'organizations_url': 'https://api.github.com/users/erikcek/orgs',
#     'repos_url': 'https://api.github.com/users/erikcek/repos',
#     'events_url': 'https://api.github.com/users/erikcek/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/erikcek/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 962,
#    'closed_issues': 922,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-10-07T21:01:24Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-10-07T21:01:24Z',
#   'updated_at': '2022-10-08T05:44:43Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Ref: https://github.com/pandas-dev/pandas/pull/48980#pullrequestreview-1134863343\r\n\r\nSimilar to #48400 with groupby, we should define methods on the `Resampler` class rather than setting them as attributes after the class definition. While this involves a little more boilerplate code, it is more straightforward to understand and easier to enhance or extend.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49000',
#   'id': 1401537211,
#   'node_id': 'PR_kwDOAA0YD85AadOY',
#   'number': 49000,
#   'title': 'CLN/TST: Remove testing ArrowExtensionArray in favor of `extensions/test_arrow.py`',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/97',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97/labels',
#    'id': 8341565,
#    'node_id': 'MI_kwDOAA0YD84Af0g9',
#    'number': 97,
#    'title': '1.6',
#    'description': '',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 11,
#    'closed_issues': 207,
#    'state': 'open',
#    'created_at': '2022-08-23T17:53:13Z',
#    'updated_at': '2022-10-08T00:28:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-10-07T18:30:22Z',
#   'updated_at': '2022-10-07T21:00:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49000',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49000',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49000.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49000.patch',
#    'merged_at': None},
#   'body': 'closes https://github.com/pandas-dev/pandas/issues/46008\r\n\r\n\r\n1. `extension/arrow/test_timestamp.py`: The original issue https://github.com/pandas-dev/pandas/issues/34986 (ExtensionDtypes with kind="M") is more-narrowly tested in https://github.com/pandas-dev/pandas/pull/48640 and the DataFrame construction is tested in `pandas/tests/extension/test_arrow.py::TestConstructors` as `ArrowDtype(pa.timestamp())` has kind="M"\r\n\r\n2. `extension/arrow/test_string.py`: Moved test to `pandas/tests/extension/test_string.py`\r\n\r\n3. `extension/arrow/test_bool.py`: Moved `test_is_bool_dtype` and `test_basic_equals` to `extensions/test_arrow.py` The rest of the test appeared to be a subset of what is tested in `test_arrow.py`\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48999',
#   'id': 1401517256,
#   'node_id': 'PR_kwDOAA0YD85AaY-G',
#   'number': 48999,
#   'title': 'CLN: test_nanops/take.py',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/97',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97/labels',
#    'id': 8341565,
#    'node_id': 'MI_kwDOAA0YD84Af0g9',
#    'number': 97,
#    'title': '1.6',
#    'description': '',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 11,
#    'closed_issues': 207,
#    'state': 'open',
#    'created_at': '2022-08-23T17:53:13Z',
#    'updated_at': '2022-10-08T00:28:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-10-07T18:09:05Z',
#   'updated_at': '2022-10-07T21:00:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48999',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48999',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48999.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48999.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48998',
#   'id': 1401472418,
#   'node_id': 'I_kwDOAA0YD85TiMWi',
#   'number': 48998,
#   'title': 'Copy-on-Write follow-up overview issue',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 183784729,
#     'node_id': 'MDU6TGFiZWwxODM3ODQ3Mjk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Master%20Tracker',
#     'name': 'Master Tracker',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'High level tracker for similar issues'},
#    {'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-10-07T17:20:14Z',
#   'updated_at': '2022-10-07T17:20:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'An initial implementation was merged in https://github.com/pandas-dev/pandas/pull/46958/ (with the proposal described in more detail in https://docs.google.com/document/d/1ZCQ9mx3LBMy-nhwRl33_jgcvWo9IWdEfxDNQ2thyTb0/edit / discussed in https://github.com/pandas-dev/pandas/issues/36195).\r\n\r\nIn https://github.com/pandas-dev/pandas/issues/36195#issuecomment-1137706149 I mentioned some next steps that are still needed; moving this to a new issue. \r\n\r\n**Implementation**\r\n\r\nComplete the API surface:\r\n\r\n- [ ] Use the lazy copy (with CoW) mechanism in more methods where it can be used\r\n- [ ] Implement the new behaviour for constructors (eg constructing a DataFrame/Series from an existing DataFrame/Series should follow the same rules as indexing -> behaves as a copy through CoW). Although, what about creating from a numpy array? \r\n- [ ] Explore / update the APIs that return numpy arrays (`.values`, `to_numpy()`). Potential idea is to make the returned array read-only by default.\r\n- [ ] Warning / error for chained setitem that no longer works\r\n\r\nImprove the performance\r\n\r\n- [ ] Optimize setitem operations to prevent copies of whole blocks (eg splitting the block could help keeping a view for all other columns, and we only take a copy for the columns that are modified) where splitting the block could keep a view for all other columns, and \r\n\r\nProvide upgrade path:\r\n\r\n- [ ] Add a warning mode that gives deprecation warnings for all cases where the current behaviour would change (initially also behind an option)\r\n\r\n\r\n**Documentation / feedback**\r\n\r\nAside from finalizing the implementation, we also need to start documenting this, and it will be super useful to have people give this a try, run their code or test suites with it, etc, so we can iron out bugs / missing warnings / or discover unexpected consequences that need to be addressed/discussed.\r\n\r\n- [ ] Document this new feature (how it works, how you can test it)\r\n- [ ] We can still add a note to the 1.5 whatsnew linking to those docs\r\n- [ ] Write a set of blogposts on the topic\r\n- [ ] Gather feedback from users / downstream packages\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48997',
#   'id': 1401467453,
#   'node_id': 'PR_kwDOAA0YD85AaOlS',
#   'number': 48997,
#   'title': 'Backport PR #48987 on branch 1.5.x (REG: Fix regression in assert_frame_equal for categorical and check_like)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
#    'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#    'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#    'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#    'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meeseeksmachine/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 93,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-10-07T23:43:34Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 6,
#   'created_at': '2022-10-07T17:14:49Z',
#   'updated_at': '2022-10-07T21:11:03Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48997',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48997',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48997.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48997.patch',
#    'merged_at': None},
#   'body': 'Backport PR #48987: REG: Fix regression in assert_frame_equal for categorical and check_like',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48996',
#   'id': 1401465363,
#   'node_id': 'PR_kwDOAA0YD85AaOIj',
#   'number': 48996,
#   'title': 'BUG: CoW - correctly track references for chained operations',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
# ...
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48967',
#   'id': 1399112465,
#   'node_id': 'I_kwDOAA0YD85TZMMR',
#   'number': 48967,
#   'title': 'PERF: Slow pandas import on Kubernetes',
#   'user': {'login': 'saul-data',
#    'id': 63714857,
#    'node_id': 'MDQ6VXNlcjYzNzE0ODU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63714857?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saul-data',
#    'html_url': 'https://github.com/saul-data',
#    'followers_url': 'https://api.github.com/users/saul-data/followers',
#    'following_url': 'https://api.github.com/users/saul-data/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/saul-data/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/saul-data/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/saul-data/subscriptions',
#    'organizations_url': 'https://api.github.com/users/saul-data/orgs',
#    'repos_url': 'https://api.github.com/users/saul-data/repos',
#    'events_url': 'https://api.github.com/users/saul-data/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/saul-data/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-10-06T08:40:20Z',
#   'updated_at': '2022-10-07T07:58:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this issue exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this issue exists on the main branch of pandas.\n\n\n### Reproducible Example\n\nThe import of Pandas 1.5 seems very slow - between 2 and 5 seconds on Openshift. Not sure if there is anyway to speed that up? I tried putting the pip files into tmpfs folder using memory volume but it is a very tricky installation and the performance benefit was marginal. Seems to be OK for Ipython like Jupyter. We use it a lot for running python scripts in a DAG / data pipeline, each python script is executed with ```/bin/sh -c python3 pythonfile.py``` using https://github.com/dataplane-app/dataplane as our data pipeline / ETL tool.\r\n\r\nHere is my test:\r\n```\r\nfrom datetime import datetime\r\n\r\nstart = datetime.now()\r\nimport pandas as pd \r\n# import redis\r\nduration = datetime.now() - start\r\n\r\nprint(str(duration))\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.10.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.0-0.bpo.9-amd64\r\nVersion          : #1 SMP Debian 5.10.70-1~bpo10+1 (2021-10-10)\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : en_US.UTF-8\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 59.6.0\r\npip              : 22.0.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : 2022.8.2\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 9.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.8.2\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : 1.4.40\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n\n\n### Prior Performance\n\nPrior versions 1.0.1 had much better import times around 1 second (still feels pretty slow). ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48966',
#   'id': 1398855129,
#   'node_id': 'PR_kwDOAA0YD85ARVAK',
#   'number': 48966,
#   'title': 'BUG: pd.compare does not recognize differences when comparing values with null Int64 data type',
#   'user': {'login': 'vamsi-verma-s',
#    'id': 40605798,
#    'node_id': 'MDQ6VXNlcjQwNjA1Nzk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40605798?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vamsi-verma-s',
#    'html_url': 'https://github.com/vamsi-verma-s',
#    'followers_url': 'https://api.github.com/users/vamsi-verma-s/followers',
#    'following_url': 'https://api.github.com/users/vamsi-verma-s/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vamsi-verma-s/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vamsi-verma-s/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vamsi-verma-s/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vamsi-verma-s/orgs',
#    'repos_url': 'https://api.github.com/users/vamsi-verma-s/repos',
#    'events_url': 'https://api.github.com/users/vamsi-verma-s/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vamsi-verma-s/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-10-06T05:55:50Z',
#   'updated_at': '2022-10-07T02:26:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48966',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48966',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48966.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48966.patch',
#    'merged_at': None},
#   'body': 'in  `pd.compare` if any comparisons result in `null` values like `pd.NA`, consider the values unequal. \r\n\r\n\r\n- [x] closes #48939 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48964',
#   'id': 1398413829,
#   'node_id': 'I_kwDOAA0YD85TWhoF',
#   'number': 48964,
#   'title': 'PERF: `pd.util.hash_pandas_object` slower on `string[pyarrow]` than `object` dtypes',
#   'user': {'login': 'jrbourbeau',
#    'id': 11656932,
#    'node_id': 'MDQ6VXNlcjExNjU2OTMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11656932?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrbourbeau',
#    'html_url': 'https://github.com/jrbourbeau',
#    'followers_url': 'https://api.github.com/users/jrbourbeau/followers',
#    'following_url': 'https://api.github.com/users/jrbourbeau/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrbourbeau/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrbourbeau/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrbourbeau/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrbourbeau/orgs',
#    'repos_url': 'https://api.github.com/users/jrbourbeau/repos',
#    'events_url': 'https://api.github.com/users/jrbourbeau/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrbourbeau/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'},
#    {'id': 1654197779,
#     'node_id': 'MDU6TGFiZWwxNjU0MTk3Nzc5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/hashing',
#     'name': 'hashing',
#     'color': '6beae0',
#     'default': False,
#     'description': 'hash_pandas_object'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-10-05T21:40:13Z',
#   'updated_at': '2022-10-07T15:22:16Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this issue exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this issue exists on the main branch of pandas.\n\n\n### Reproducible Example\n\nWhen investigating Dask\'s shuffle performance on `string[pyarrow]` data, I observed `pd.util.hash_pandas_object` was slightly less performant on `string[pyarrow]` data than on regular `object` Python objects. This surprised me as I would have expected hashing `pyarrow`-backed data to be faster than Python objects\r\n\r\n```python\r\nIn [1]: import pandas as pd\r\n\r\nIn [2]: s = pd.Series(range(2_000))\r\n\r\nIn [3]: s_object = s.astype(object)\r\n\r\nIn [4]: s_pyarrow = s.astype("string[pyarrow]")\r\n\r\nIn [5]: %timeit pd.util.hash_pandas_object(s_object)\r\n859 µs ± 11.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)\r\n\r\nIn [6]: %timeit pd.util.hash_pandas_object(s_pyarrow)\r\n1.01 ms ± 29.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.10.6.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.6.0\r\nVersion          : Darwin Kernel Version 21.6.0: Wed Aug 10 14:25:27 PDT 2022; root:xnu-8020.141.5~2/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.4\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.4.1\r\npip              : 22.2.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.5.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 9.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n</details>\r\n\n\n### Prior Performance\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1) # for finding how many unique dict are there
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])  # for printing user if from all 30 dict
# Out:
# 9801748
# 10647082
# 88912209
# 39504233
# 45562402
# 10647082
# 10647082
# 1020496
# 39504233
# 1020496
# 61934744
# 10058240
# 6564007
# 61934744
# 79214952
# 5585221
# 6564007
# 79214952
# 38273482
# 45562402
# 8078968
# 605452
# 28356592
# 33491632
# 10647082
# 7980666
# 33491632
# 63714857
# 40605798
# 11656932

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49005',
#   'id': 1401793191,
#   'node_id': 'PR_kwDOAA0YD85AbTgP',
#   'number': 49005,
#   'title': 'DOC: Fix typos and standardize spelling of "GitHub"  and "macOS"',
#   'user': {'login': 'gcbeltramini',
#    'id': 9801748,
#    'node_id': 'MDQ6VXNlcjk4MDE3NDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9801748?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gcbeltramini',
#    'html_url': 'https://github.com/gcbeltramini',
#    'followers_url': 'https://api.github.com/users/gcbeltramini/followers',
#    'following_url': 'https://api.github.com/users/gcbeltramini/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gcbeltramini/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gcbeltramini/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gcbeltramini/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gcbeltramini/orgs',
#    'repos_url': 'https://api.github.com/users/gcbeltramini/repos',
#    'events_url': 'https://api.github.com/users/gcbeltramini/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gcbeltramini/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-10-08T02:30:47Z',
#   'updated_at': '2022-10-08T02:31:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49005',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49005',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49005.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49005.patch',
#    'merged_at': None},
#   'body': '## Proposed changes\r\n\r\n1. Fix some typos. They were found with:\r\n\r\n   ```shell\r\n   brew install aspell\r\n   \r\n   find . -type f -exec cat \'{}\' \\; |\r\n     aspell -a |\r\n     grep -v \'*\' |\r\n     sed \'/^$/d\' |\r\n     cut -d \' \' -f 2 |\r\n     sort -u\r\n   ```\r\n\r\n   The output was visually inspected to find the typos.\r\n\r\n3. Standardize spelling of "GitHub". The official spelling of "GitHub" can be seen in the title of page <https://github.com/>.\r\n4. Standardize spelling of "macOS". The Apple operating system was called "Mac OS X" in versions 10.0-10.7, then "OS X" in versions 10.8-10.11, and finally "macOS" since version 10.12, released in 2016 (<https://en.wikipedia.org/wiki/MacOS#Release_history>).\r\n\r\n## Checklist\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49005/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49004',
#   'id': 1401686191,
#   'node_id': 'PR_kwDOAA0YD85Aa9EU',
#   'number': 49004,
#   'title': 'CLN/TST: Use fixture instead of setup_method',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-10-07T21:37:19Z',
#   'updated_at': '2022-10-07T22:48:04Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49004',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49004',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49004.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49004.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49004/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49003',
#   'id': 1401674993,
#   'node_id': 'I_kwDOAA0YD85Ti9zx',
#   'number': 49003,
#   'title': 'BUG: .astype(int) in Window vs Mac',
#   'user': {'login': 'FeiLi1996',
#    'id': 88912209,
#    'node_id': 'MDQ6VXNlcjg4OTEyMjA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88912209?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FeiLi1996',
#    'html_url': 'https://github.com/FeiLi1996',
#    'followers_url': 'https://api.github.com/users/FeiLi1996/followers',
#    'following_url': 'https://api.github.com/users/FeiLi1996/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/FeiLi1996/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/FeiLi1996/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/FeiLi1996/subscriptions',
#    'organizations_url': 'https://api.github.com/users/FeiLi1996/orgs',
#    'repos_url': 'https://api.github.com/users/FeiLi1996/repos',
#    'events_url': 'https://api.github.com/users/FeiLi1996/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/FeiLi1996/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-10-07T21:19:36Z',
#   'updated_at': '2022-10-07T23:08:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nHypothetical example. I can\'t give an actual example because it is company stuff,\r\n```python\r\nipdb> ids.astype(int) #on Mac\r\nid(before)      id(after) \r\n1818726176      1818726176  \r\n1881879486      1881879486  \r\n2590366906      2590366906 \r\n\r\nipdb> ids.astype(int) #on Window\r\nid(before)      id(after) \r\n1818726176      1818726176\r\n1881879486      1881879486\r\n2590366906     -1704600390\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nI encounter an issue similiar to this one on stackoverflow\r\nhttps://stackoverflow.com/questions/67796096/working-around-the-windows-numpy-astypeint-bug-in-pandas\r\n\r\nThe story is that my coworker was using Mac and I was using Window. We were getting different numbers in our report. Discrepancy of 179  counts vs 1730 counts of something.\r\n\r\nI debugged everyline of code until I got the change at ".astype(int)". For some reason , Mac decided to turn it to int64 and Window turned it into int32. However, some of the ids number are over the cap of int32, so the computer changed the number to something else like you seen the example above 2590366906   >>> -1704600390 . Pandas didn\'t throw an error or give me a warning. So I  did a left join down the line on the id=id and lots of my data were gone.\r\n\r\n\r\n\r\n\r\n### Expected Behavior\r\n\r\nThe expected behavior should be that Pandas throw an error or at least give me a warning that this happened.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.8.3.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19041\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 41.2.0\r\npip              : 19.2.3\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : 1.0.9\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.0\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.1\r\nsnappy           : None\r\nsqlalchemy       : 1.4.41\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49003/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49002',
#   'id': 1401670247,
#   'node_id': 'PR_kwDOAA0YD85Aa5os',
#   'number': 49002,
#   'title': 'Backport PR #48412 on branch 1.5.x (BUG: safe_sort losing MultiIndex dtypes)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
#    'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#    'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#    'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#    'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meeseeksmachine/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 93,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-10-07T23:43:34Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-10-07T21:12:40Z',
#   'updated_at': '2022-10-07T21:12:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49002',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49002',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49002.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49002.patch',
#    'merged_at': None},
#   'body': 'Backport PR #48412: BUG: safe_sort losing MultiIndex dtypes',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49002/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49001',
#   'id': 1401662423,
#   'node_id': 'I_kwDOAA0YD85Ti6vX',
#   'number': 49001,
#   'title': 'REF: Define ops on Resampler as normal methods',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 74975453,
#     'node_id': 'MDU6TGFiZWw3NDk3NTQ1Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Resample',
#     'name': 'Resample',
#     'color': '207de5',
#     'default': False,
#     'description': 'resample method'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'erikcek',
#    'id': 32076170,
#    'node_id': 'MDQ6VXNlcjMyMDc2MTcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32076170?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/erikcek',
#    'html_url': 'https://github.com/erikcek',
#    'followers_url': 'https://api.github.com/users/erikcek/followers',
#    'following_url': 'https://api.github.com/users/erikcek/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/erikcek/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/erikcek/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/erikcek/subscriptions',
#    'organizations_url': 'https://api.github.com/users/erikcek/orgs',
#    'repos_url': 'https://api.github.com/users/erikcek/repos',
#    'events_url': 'https://api.github.com/users/erikcek/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/erikcek/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'erikcek',
#     'id': 32076170,
#     'node_id': 'MDQ6VXNlcjMyMDc2MTcw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/32076170?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/erikcek',
#     'html_url': 'https://github.com/erikcek',
#     'followers_url': 'https://api.github.com/users/erikcek/followers',
#     'following_url': 'https://api.github.com/users/erikcek/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/erikcek/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/erikcek/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/erikcek/subscriptions',
#     'organizations_url': 'https://api.github.com/users/erikcek/orgs',
#     'repos_url': 'https://api.github.com/users/erikcek/repos',
#     'events_url': 'https://api.github.com/users/erikcek/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/erikcek/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 962,
#    'closed_issues': 922,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-10-07T21:01:24Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-10-07T21:01:24Z',
#   'updated_at': '2022-10-08T05:44:43Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Ref: https://github.com/pandas-dev/pandas/pull/48980#pullrequestreview-1134863343\r\n\r\nSimilar to #48400 with groupby, we should define methods on the `Resampler` class rather than setting them as attributes after the class definition. While this involves a little more boilerplate code, it is more straightforward to understand and easier to enhance or extend.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49001/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49000',
#   'id': 1401537211,
#   'node_id': 'PR_kwDOAA0YD85AadOY',
#   'number': 49000,
#   'title': 'CLN/TST: Remove testing ArrowExtensionArray in favor of `extensions/test_arrow.py`',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/97',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97/labels',
#    'id': 8341565,
#    'node_id': 'MI_kwDOAA0YD84Af0g9',
#    'number': 97,
#    'title': '1.6',
#    'description': '',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 11,
#    'closed_issues': 207,
#    'state': 'open',
#    'created_at': '2022-08-23T17:53:13Z',
#    'updated_at': '2022-10-08T00:28:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-10-07T18:30:22Z',
#   'updated_at': '2022-10-07T21:00:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49000',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49000',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49000.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49000.patch',
#    'merged_at': None},
#   'body': 'closes https://github.com/pandas-dev/pandas/issues/46008\r\n\r\n\r\n1. `extension/arrow/test_timestamp.py`: The original issue https://github.com/pandas-dev/pandas/issues/34986 (ExtensionDtypes with kind="M") is more-narrowly tested in https://github.com/pandas-dev/pandas/pull/48640 and the DataFrame construction is tested in `pandas/tests/extension/test_arrow.py::TestConstructors` as `ArrowDtype(pa.timestamp())` has kind="M"\r\n\r\n2. `extension/arrow/test_string.py`: Moved test to `pandas/tests/extension/test_string.py`\r\n\r\n3. `extension/arrow/test_bool.py`: Moved `test_is_bool_dtype` and `test_basic_equals` to `extensions/test_arrow.py` The rest of the test appeared to be a subset of what is tested in `test_arrow.py`\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49000/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48999',
#   'id': 1401517256,
#   'node_id': 'PR_kwDOAA0YD85AaY-G',
#   'number': 48999,
#   'title': 'CLN: test_nanops/take.py',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/97',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97/labels',
#    'id': 8341565,
#    'node_id': 'MI_kwDOAA0YD84Af0g9',
#    'number': 97,
#    'title': '1.6',
#    'description': '',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 11,
#    'closed_issues': 207,
#    'state': 'open',
#    'created_at': '2022-08-23T17:53:13Z',
#    'updated_at': '2022-10-08T00:28:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-10-07T18:09:05Z',
#   'updated_at': '2022-10-07T21:00:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48999',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48999',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48999.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48999.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48999/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48998',
#   'id': 1401472418,
#   'node_id': 'I_kwDOAA0YD85TiMWi',
#   'number': 48998,
#   'title': 'Copy-on-Write follow-up overview issue',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 183784729,
#     'node_id': 'MDU6TGFiZWwxODM3ODQ3Mjk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Master%20Tracker',
#     'name': 'Master Tracker',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'High level tracker for similar issues'},
#    {'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-10-07T17:20:14Z',
#   'updated_at': '2022-10-07T17:20:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'An initial implementation was merged in https://github.com/pandas-dev/pandas/pull/46958/ (with the proposal described in more detail in https://docs.google.com/document/d/1ZCQ9mx3LBMy-nhwRl33_jgcvWo9IWdEfxDNQ2thyTb0/edit / discussed in https://github.com/pandas-dev/pandas/issues/36195).\r\n\r\nIn https://github.com/pandas-dev/pandas/issues/36195#issuecomment-1137706149 I mentioned some next steps that are still needed; moving this to a new issue. \r\n\r\n**Implementation**\r\n\r\nComplete the API surface:\r\n\r\n- [ ] Use the lazy copy (with CoW) mechanism in more methods where it can be used\r\n- [ ] Implement the new behaviour for constructors (eg constructing a DataFrame/Series from an existing DataFrame/Series should follow the same rules as indexing -> behaves as a copy through CoW). Although, what about creating from a numpy array? \r\n- [ ] Explore / update the APIs that return numpy arrays (`.values`, `to_numpy()`). Potential idea is to make the returned array read-only by default.\r\n- [ ] Warning / error for chained setitem that no longer works\r\n\r\nImprove the performance\r\n\r\n- [ ] Optimize setitem operations to prevent copies of whole blocks (eg splitting the block could help keeping a view for all other columns, and we only take a copy for the columns that are modified) where splitting the block could keep a view for all other columns, and \r\n\r\nProvide upgrade path:\r\n\r\n- [ ] Add a warning mode that gives deprecation warnings for all cases where the current behaviour would change (initially also behind an option)\r\n\r\n\r\n**Documentation / feedback**\r\n\r\nAside from finalizing the implementation, we also need to start documenting this, and it will be super useful to have people give this a try, run their code or test suites with it, etc, so we can iron out bugs / missing warnings / or discover unexpected consequences that need to be addressed/discussed.\r\n\r\n- [ ] Document this new feature (how it works, how you can test it)\r\n- [ ] We can still add a note to the 1.5 whatsnew linking to those docs\r\n- [ ] Write a set of blogposts on the topic\r\n- [ ] Gather feedback from users / downstream packages\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48998/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48997',
#   'id': 1401467453,
#   'node_id': 'PR_kwDOAA0YD85AaOlS',
#   'number': 48997,
#   'title': 'Backport PR #48987 on branch 1.5.x (REG: Fix regression in assert_frame_equal for categorical and check_like)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
#    'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#    'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#    'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#    'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meeseeksmachine/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 93,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-10-07T23:43:34Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 6,
#   'created_at': '2022-10-07T17:14:49Z',
#   'updated_at': '2022-10-07T21:11:03Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48997',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48997',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48997.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48997.patch',
#    'merged_at': None},
#   'body': 'Backport PR #48987: REG: Fix regression in assert_frame_equal for categorical and check_like',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48997/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48996/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48996',
#   'id': 1401465363,
#   'node_id': 'PR_kwDOAA0YD85AaOIj',
#   'number': 48996,
#   'title': 'BUG: CoW - correctly track references for chained operations',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
# ...
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48967',
#   'id': 1399112465,
#   'node_id': 'I_kwDOAA0YD85TZMMR',
#   'number': 48967,
#   'title': 'PERF: Slow pandas import on Kubernetes',
#   'user': {'login': 'saul-data',
#    'id': 63714857,
#    'node_id': 'MDQ6VXNlcjYzNzE0ODU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63714857?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saul-data',
#    'html_url': 'https://github.com/saul-data',
#    'followers_url': 'https://api.github.com/users/saul-data/followers',
#    'following_url': 'https://api.github.com/users/saul-data/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/saul-data/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/saul-data/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/saul-data/subscriptions',
#    'organizations_url': 'https://api.github.com/users/saul-data/orgs',
#    'repos_url': 'https://api.github.com/users/saul-data/repos',
#    'events_url': 'https://api.github.com/users/saul-data/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/saul-data/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-10-06T08:40:20Z',
#   'updated_at': '2022-10-07T07:58:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this issue exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this issue exists on the main branch of pandas.\n\n\n### Reproducible Example\n\nThe import of Pandas 1.5 seems very slow - between 2 and 5 seconds on Openshift. Not sure if there is anyway to speed that up? I tried putting the pip files into tmpfs folder using memory volume but it is a very tricky installation and the performance benefit was marginal. Seems to be OK for Ipython like Jupyter. We use it a lot for running python scripts in a DAG / data pipeline, each python script is executed with ```/bin/sh -c python3 pythonfile.py``` using https://github.com/dataplane-app/dataplane as our data pipeline / ETL tool.\r\n\r\nHere is my test:\r\n```\r\nfrom datetime import datetime\r\n\r\nstart = datetime.now()\r\nimport pandas as pd \r\n# import redis\r\nduration = datetime.now() - start\r\n\r\nprint(str(duration))\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.10.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.0-0.bpo.9-amd64\r\nVersion          : #1 SMP Debian 5.10.70-1~bpo10+1 (2021-10-10)\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : en_US.UTF-8\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 59.6.0\r\npip              : 22.0.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : 2022.8.2\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 9.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.8.2\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : 1.4.40\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n\n\n### Prior Performance\n\nPrior versions 1.0.1 had much better import times around 1 second (still feels pretty slow). ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48967/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48966',
#   'id': 1398855129,
#   'node_id': 'PR_kwDOAA0YD85ARVAK',
#   'number': 48966,
#   'title': 'BUG: pd.compare does not recognize differences when comparing values with null Int64 data type',
#   'user': {'login': 'vamsi-verma-s',
#    'id': 40605798,
#    'node_id': 'MDQ6VXNlcjQwNjA1Nzk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40605798?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vamsi-verma-s',
#    'html_url': 'https://github.com/vamsi-verma-s',
#    'followers_url': 'https://api.github.com/users/vamsi-verma-s/followers',
#    'following_url': 'https://api.github.com/users/vamsi-verma-s/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vamsi-verma-s/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vamsi-verma-s/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vamsi-verma-s/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vamsi-verma-s/orgs',
#    'repos_url': 'https://api.github.com/users/vamsi-verma-s/repos',
#    'events_url': 'https://api.github.com/users/vamsi-verma-s/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vamsi-verma-s/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-10-06T05:55:50Z',
#   'updated_at': '2022-10-07T02:26:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48966',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48966',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48966.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48966.patch',
#    'merged_at': None},
#   'body': 'in  `pd.compare` if any comparisons result in `null` values like `pd.NA`, consider the values unequal. \r\n\r\n\r\n- [x] closes #48939 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48966/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48964',
#   'id': 1398413829,
#   'node_id': 'I_kwDOAA0YD85TWhoF',
#   'number': 48964,
#   'title': 'PERF: `pd.util.hash_pandas_object` slower on `string[pyarrow]` than `object` dtypes',
#   'user': {'login': 'jrbourbeau',
#    'id': 11656932,
#    'node_id': 'MDQ6VXNlcjExNjU2OTMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11656932?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrbourbeau',
#    'html_url': 'https://github.com/jrbourbeau',
#    'followers_url': 'https://api.github.com/users/jrbourbeau/followers',
#    'following_url': 'https://api.github.com/users/jrbourbeau/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrbourbeau/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrbourbeau/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrbourbeau/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrbourbeau/orgs',
#    'repos_url': 'https://api.github.com/users/jrbourbeau/repos',
#    'events_url': 'https://api.github.com/users/jrbourbeau/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrbourbeau/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'},
#    {'id': 1654197779,
#     'node_id': 'MDU6TGFiZWwxNjU0MTk3Nzc5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/hashing',
#     'name': 'hashing',
#     'color': '6beae0',
#     'default': False,
#     'description': 'hash_pandas_object'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-10-05T21:40:13Z',
#   'updated_at': '2022-10-07T15:22:16Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this issue exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this issue exists on the main branch of pandas.\n\n\n### Reproducible Example\n\nWhen investigating Dask\'s shuffle performance on `string[pyarrow]` data, I observed `pd.util.hash_pandas_object` was slightly less performant on `string[pyarrow]` data than on regular `object` Python objects. This surprised me as I would have expected hashing `pyarrow`-backed data to be faster than Python objects\r\n\r\n```python\r\nIn [1]: import pandas as pd\r\n\r\nIn [2]: s = pd.Series(range(2_000))\r\n\r\nIn [3]: s_object = s.astype(object)\r\n\r\nIn [4]: s_pyarrow = s.astype("string[pyarrow]")\r\n\r\nIn [5]: %timeit pd.util.hash_pandas_object(s_object)\r\n859 µs ± 11.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)\r\n\r\nIn [6]: %timeit pd.util.hash_pandas_object(s_pyarrow)\r\n1.01 ms ± 29.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.10.6.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.6.0\r\nVersion          : Darwin Kernel Version 21.6.0: Wed Aug 10 14:25:27 PDT 2022; root:xnu-8020.141.5~2/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.4\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.4.1\r\npip              : 22.2.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.5.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 9.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n</details>\r\n\n\n### Prior Performance\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48964/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
df2 = pd.DataFrame(data1 , columns=['id','url' , 'repository_url' , 'labels_url','user'])

# here columns attribute will only take the respective col and make DataFrame form those col only leving the rest

# %%
df2
# Out:
#             id                                                url  \
# 0   1401793191  https://api.github.com/repos/pandas-dev/pandas...
# 1   1401686191  https://api.github.com/repos/pandas-dev/pandas...
# 2   1401674993  https://api.github.com/repos/pandas-dev/pandas...
# 3   1401670247  https://api.github.com/repos/pandas-dev/pandas...
# 4   1401662423  https://api.github.com/repos/pandas-dev/pandas...
# 5   1401537211  https://api.github.com/repos/pandas-dev/pandas...
# 6   1401517256  https://api.github.com/repos/pandas-dev/pandas...
# 7   1401472418  https://api.github.com/repos/pandas-dev/pandas...
# 8   1401467453  https://api.github.com/repos/pandas-dev/pandas...
# 9   1401465363  https://api.github.com/repos/pandas-dev/pandas...
# 10  1401461137  https://api.github.com/repos/pandas-dev/pandas...
# 11  1401226127  https://api.github.com/repos/pandas-dev/pandas...
# 12  1401123136  https://api.github.com/repos/pandas-dev/pandas...
# 13  1401012917  https://api.github.com/repos/pandas-dev/pandas...
# 14  1400944644  https://api.github.com/repos/pandas-dev/pandas...
# 15  1400902684  https://api.github.com/repos/pandas-dev/pandas...
# 16  1400834210  https://api.github.com/repos/pandas-dev/pandas...
# 17  1400819533  https://api.github.com/repos/pandas-dev/pandas...
# 18  1400807015  https://api.github.com/repos/pandas-dev/pandas...
# 19  1400622262  https://api.github.com/repos/pandas-dev/pandas...
# 20  1400364547  https://api.github.com/repos/pandas-dev/pandas...
# 21  1400281534  https://api.github.com/repos/pandas-dev/pandas...
# 22  1400211273  https://api.github.com/repos/pandas-dev/pandas...
# 23  1400053706  https://api.github.com/repos/pandas-dev/pandas...
# 24  1400041573  https://api.github.com/repos/pandas-dev/pandas...
# 25  1399969018  https://api.github.com/repos/pandas-dev/pandas...
# 26  1399659123  https://api.github.com/repos/pandas-dev/pandas...
# 27  1399112465  https://api.github.com/repos/pandas-dev/pandas...
# 28  1398855129  https://api.github.com/repos/pandas-dev/pandas...
# 29  1398413829  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'gcbeltramini', 'id': 9801748, 'node...
# 1   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 2   {'login': 'FeiLi1996', 'id': 88912209, 'node_i...
# 3   {'login': 'meeseeksmachine', 'id': 39504233, '...
# 4   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 5   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 7   {'login': 'jorisvandenbossche', 'id': 1020496,...
# 8   {'login': 'meeseeksmachine', 'id': 39504233, '...
# 9   {'login': 'jorisvandenbossche', 'id': 1020496,...
# 10  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 11  {'login': 'datapythonista', 'id': 10058240, 'n...
# 12  {'login': 'noatamir', 'id': 6564007, 'node_id'...
# 13  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 14  {'login': 'DanielGoncalves47264', 'id': 792149...
# 15  {'login': 'bashtage', 'id': 5585221, 'node_id'...
# 16  {'login': 'noatamir', 'id': 6564007, 'node_id'...
# 17  {'login': 'DanielGoncalves47264', 'id': 792149...
# 18  {'login': 'jetale', 'id': 38273482, 'node_id':...
# 19  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 20  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 21  {'login': 'ligon', 'id': 605452, 'node_id': 'M...
# 22  {'login': 'Sherry3', 'id': 28356592, 'node_id'...
# 23  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 24  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 25  {'login': 'tehunter', 'id': 7980666, 'node_id'...
# 26  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 27  {'login': 'saul-data', 'id': 63714857, 'node_i...
# 28  {'login': 'vamsi-verma-s', 'id': 40605798, 'no...
# 29  {'login': 'jrbourbeau', 'id': 11656932, 'node_...

# %%
df2.to_csv('json_res.csv')
# saving it to local dir in csv format

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6C26-E0CC
#
#  Directory of C:\Users\poswa\Pandass
#
# 08-10-2022  11:59 AM    <DIR>          .
# 08-10-2022  11:59 AM    <DIR>          ..
# 08-10-2022  11:30 AM    <DIR>          .ipynb_checkpoints
# 08-10-2022  11:38 AM             5,833 cricket.csv
# 08-10-2022  11:59 AM            35,260 json_res.csv
# 08-10-2022  11:14 AM            90,261 my1.ipynb
# 08-10-2022  11:38 AM            78,961 NBA.csv
# 08-10-2022  11:58 AM           576,031 pandas day 2.ipynb
# 08-10-2022  11:29 AM           292,824 PandasLec1.ipynb
# 08-10-2022  10:42 AM            37,423 Untitled.ipynb
#                7 File(s)      1,116,593 bytes
#                3 Dir(s)  136,469,676,032 bytes free

# %%
df2 = pd.DataFrame(data1['user'] , columns=['id','url' , 'repository_url' , 'labels_url','user'])

# %%
type(data1)
# Out:
# list
